# %% [markdown]
# <a href="https://colab.research.google.com/github/garden-jun/DeepLearning-from-scratch/blob/main/3%EC%9E%A5%20%EC%8B%A0%EA%B2%BD%EB%A7%9D/3.3%20%EB%8B%A4%EC%B0%A8%EC%9B%90%20%EB%B0%B0%EC%97%B4%EC%9D%98%20%EA%B3%84%EC%82%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **3.3.1 다차원 배열**
# 숫자를 N차원으로 나열하는 것을 통틀어 다차원 배열이라고 한다.

# %%
# 1차원배열
import numpy as np
A = np.array([1,2,3,4])
print(A)            # [1 2 3 4]

print(np.ndim(A))   # 배열의 차원 수 확인 # 1

print(A.shape)      # 배열의 형상   # (4, )
print(A.shape[0])   # 4
# Out:
# [1 2 3 4]
# 1
# (4,)
# 4

# %%
# 2차원 배열
B = np.array([[1,2], [3,4], [5,6]])
print(B)

print(np.ndim(B))  # 2
print(B.shape)     # (3, 2)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# 2
# (3, 2)

# %% [markdown]
# ## **3.3.2 행렬의 내적(행렬 곱)**
#
# 행렬의 내적을 구하는법
# ![image.png](data:image/png;base64,...)
# 그림에서처럼 왼쪽 행렬의 행과 오른쪽 행렬의 열을 원소별로 곱하고 그 값들을 더해서 계산합니다.
#
# 다음은 행렬곱 계산을 파이썬으로 구현 한 것입니다.

# %%
# 2X3 행렬과 3X2 행렬의 곱
A = np.array([[1,2,3], [4,5,6]])
print(A.shape)  # (2,3)

B = np.array([[1,2], [3,4], [5,6]])
print(B.shape)  # (3,2)

print(np.dot(A, B)) # 행렬 곱 출력
# Out:
# (2, 3)
# (3, 2)
# [[22 28]
#  [49 64]]

# %%
A = np.array([[1,2], [3,4]])
print(A.shape)   # (2,2)

B = np.array([[5,6], [7,8]])
print(B.shape)   # (2,2)

print(np.dot(A, B))  # 행렬의 내적을 계산하는 함수
# Out:
# (2, 2)
# (2, 2)
# [[19 22]
#  [43 50]]

# %% [markdown]
# 행렬곱은 앞행렬의 열수와 뒤 행렬의 행수 가 일치해야 한다.
#
#     A X B = C일때
#     C의 형상은 A의 행 수와 C의 열 수가 된다.

# %% [markdown]
# ## **3.3.3 신경망의 내적**
#
# 가중치만 갖는 간단한 신경망을 구현해보자.
# ![image.png](data:image/png;base64,...)

# %%
X = np.array([1,2])
print(X.shape)  # (2, )

W = np.array([[1, 3, 5], [2, 4, 6]])
print(W)
print(W.shape)  # (2, 3)

Y = np.dot(X, W)
print(Y)        #[ 5 11 17]
# Out:
# (2,)
# [[1 3 5]
#  [2 4 6]]
# (2, 3)
# [ 5 11 17]

# %% [markdown]
# 다차원 배열의 내적을 구해주는 np.dot함수를 사용하면 이처럼 단번에 결과 Y를 계산할 수 있습니다.
